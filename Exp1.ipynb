# %%
# !pip install transformers torch -q

# %%
from transformers import pipeline

print("Loading GPT-2 model...")

generator = pipeline(
    "text-generation",
    model="gpt2"
)

print("Model loaded successfully!")
# Out:
# Loading GPT-2 model...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Model loaded successfully!

# %%
headline = "Government launches new AI policy"

result = generator(
    headline,
    max_length=150,
    num_return_sequences=1,
    temperature=0.8
)

print("Headline:")
print(headline)

print("\nGenerated News Article:\n")
print(result[0]["generated_text"])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Headline:
# Government launches new AI policy
#
# Generated News Article:
#
# Government launches new AI policy
#
# By Mark Gourlay
#
# 15 June 2014
#
# The United States and its allies are threatening to launch a new aggressive policy aimed at stopping the spread of Islamic State militants from the Middle East.
#
# United Nations agencies announced in January a new phase in their war against the militant group. The international coalition is expected to begin its work in earnest on the battle against Islamic State in Mosul, Iraq, on 20 June and continue fighting Islamic State militants in Syria, and in Iraq, Syria and Libya.
#
# The US and its allies, including France and Germany, are planning to launch a series of strikes in Syria and Iraq, the main targets of their attacks. This, along with their air strikes in northern Iraq and Syria, will make it impossible for Islamic State militants to infiltrate the country's borders.
#
# But the Pentagon and its allies have been making clear this new phase will not be accompanied by a new policy. Some diplomats have suggested that the US and its allies are willing to cut back on their air campaign in Syria and Iraq, as long as they achieve a credible ceasefire.
#
# The American and European powers are already discussing a new policy that their allies fear could lead to more attacks.
#
# The United States and its allies are already making clear

# %%
# !pip install transformers torch -q

from transformers import pipeline

print("Loading GPT-2 model...")
generator = pipeline("text-generation", model="gpt2")

headline = input("Enter a News Headline: ")

generated_news = generator(
    headline,
    max_length=200,
    num_return_sequences=1,
    temperature=0.7,
    do_sample=True
)

print("\n" + "="*50)
print("GENERATED NEWS ARTICLE")
print("="*50)
print(generated_news[0]["generated_text"])
# Out:
# Loading GPT-2 model...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a News Headline: Effect Of AI On Social Media.
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'temperature', 'max_length', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ==================================================
# GENERATED NEWS ARTICLE
# ==================================================
# Effect Of AI On Social Media.
#
# The most recent AI research, released by Microsoft, found that AI is likely more popular than it should be in the future. In fact, the number of people who are engaged in social media is already well above the average of the rest of the population.
#
# The research led to the first evidence that social media could have an effect on the way people interact with social media content. In August, Microsoft released the first evidence that social media was actually the cause of social media engagement in the U.S.
#
# The study is the first to show that social media is the driving force behind people's engagement in social media posts.
#
# Social media can play a critical role in the creation of a social media profile. While not as important as your own personal profile, it can help you connect with other people and gain insight into their personal lives.
#
# In fact, research conducted by the National Institute on Aging found that people who read less about themselves online were more likely to post something negative, and their profile photos were less likely to have a positive impact than the image they had.
#
# Researchers studied the effects of social media on social media users' daily interactions with their friends and family.
#
# Researchers found that users rated their interaction with friends and family
